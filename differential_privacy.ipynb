# %% [markdown]
# <a href="https://colab.research.google.com/github/abojha/dataPrivacyLab/blob/main/differential_privacy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/content/drive/MyDrive/DP_Lab/preprocessed_adult.csv")

# %%
df
# Out:
#        age     education   relationship     sex                race income
# 0       56       HS-grad        Husband    Male               White   >50K
# 1       56           9th        Husband    Male               Black  <=50K
# 2       55       HS-grad      Unmarried  Female  Amer-Indian-Eskimo  <=50K
# 3       42     Doctorate  Not-in-family    Male               White   >50K
# 4       60  Some-college        Husband    Male               White   >50K
# ...    ...           ...            ...     ...                 ...    ...
# 15677   39       HS-grad        Husband    Male               White  <=50K
# 15678   40     Doctorate        Husband    Male               White   >50K
# 15679   42       HS-grad      Unmarried  Female               White  <=50K
# 15680   51     Assoc-voc        Husband    Male               White  <=50K
# 15681   22          12th  Not-in-family    Male  Amer-Indian-Eskimo  <=50K
#
# [15682 rows x 6 columns]

# %%
quasi_identifiers = ["age", "education", "relationship", "sex", "race"]


df["income"] = df["income"].apply(lambda x: np.random.randint(20000, 90000) if x == "<=50K" else np.random.randint(50000, 150000))
sensitive_attribute = "income"

# %%
df
# Out:
#        age     education   relationship     sex                race  income
# 0       56       HS-grad        Husband    Male               White  125007
# 1       56           9th        Husband    Male               Black   52078
# 2       55       HS-grad      Unmarried  Female  Amer-Indian-Eskimo   23868
# 3       42     Doctorate  Not-in-family    Male               White  121759
# 4       60  Some-college        Husband    Male               White   75153
# ...    ...           ...            ...     ...                 ...     ...
# 15677   39       HS-grad        Husband    Male               White   63626
# 15678   40     Doctorate        Husband    Male               White   99081
# 15679   42       HS-grad      Unmarried  Female               White   60827
# 15680   51     Assoc-voc        Husband    Male               White   73571
# 15681   22          12th  Not-in-family    Male  Amer-Indian-Eskimo   83728
#
# [15682 rows x 6 columns]

# %%
sensitive_attribute = "income"

# Define sensitivity (max change in `income` for one record change)
sensitivity = df[sensitive_attribute].max() - df[sensitive_attribute].min()

# Apply Laplace noise
epsilon_used = 1.0  # Theoretical epsilon used for noise
df["noisy_income"] = df[sensitive_attribute] + np.random.laplace(loc=0, scale=sensitivity/epsilon_used, size=len(df))

# Estimate actual noise added
noise = df["noisy_income"] - df[sensitive_attribute]
avg_noise = np.abs(noise).mean()

# Compute estimated epsilon
estimated_epsilon = sensitivity / avg_noise

print(f"Estimated ε (epsilon) for Differential Privacy: {estimated_epsilon:.2f}")
# Out:
# Estimated ε (epsilon) for Differential Privacy: 1.00

# %% [markdown]
#  **If estimated ε is close to the intended ε (e.g., 1.0), it means the Laplace mechanism is correctly implemented.
# If ε is too high (> 2.0), it means the privacy guarantee is weak (too much information leakage).
# If ε is too low (< 0.5), the data might be too noisy, reducing utility.**
